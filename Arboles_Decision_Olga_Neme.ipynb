# %% [markdown]
# ARBOLES DE DECISION

# %% [markdown]
# Olga Yamile Neme Castro

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
Datos = pd.read_csv('C:/Users/daveg/Desktop/winequality-red.csv')

# %%
Datos.head(30)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %%
Datos.shape
# Out:
# (1599, 12)

# %%
Datos.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
Datos.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
plt.hist(Datos.quality)
# Out:
# (array([ 10.,   0.,  53.,   0., 681.,   0., 638.,   0., 199.,  18.]),
#  array([3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. , 7.5, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(6,3))
sns.boxplot(x=Datos['fixed acidity'])
plt.title('Identificacion de datos faltantes y atipicos en Nivel de Acidez', fontsize=10)
# Out:
# Text(0.5, 1.0, 'Identificacion de datos faltantes y atipicos en Nivel de Acidez')

# %%
plt.figure(figsize=(10,3))
sns.boxplot(x=Datos['residual sugar'])
plt.title('Identificacion de datos faltantes y atipicos en Nivel de Azucar', fontsize=10)
# Out:
# Text(0.5, 1.0, 'Identificacion de datos faltantes y atipicos en Nivel de Azucar')

# %%
plt.figure(figsize=(10,3))
sns.boxplot(x=Datos['pH'])
plt.title('Identificacion de datos faltantes y atipicos en Nivel de PH', fontsize=10)
# Out:
# Text(0.5, 1.0, 'Identificacion de datos faltantes y atipicos en Nivel de PH')

# %%
plt.figure(figsize=(10,3))
sns.boxplot(x=Datos['alcohol'])
plt.title('Identificacion de datos faltantes y atipicos en Nivel de Alcohol', fontsize=10)
# Out:
# Text(0.5, 1.0, 'Identificacion de datos faltantes y atipicos en Nivel de Alcohol')

# %%
Datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
Datos.dropna()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
Datos = Datos.drop_duplicates()

# %%
X = Datos.drop(columns='quality')
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y = Datos['quality']
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 5       5
#        ..
# 1593    6
# 1594    5
# 1595    6
# 1597    5
# 1598    6
# Name: quality, Length: 1359, dtype: int64

# %%
predictors_col = ["fixed acidity", "residual sugar", "pH", "alcohol"]
target_col = ['quality']

# %%
predictors = Datos[predictors_col]
target = Datos[target_col]

# %%
predictors
# Out:
#       fixed acidity  residual sugar    pH  alcohol
# 0               7.4             1.9  3.51      9.4
# 1               7.8             2.6  3.20      9.8
# 2               7.8             2.3  3.26      9.8
# 3              11.2             1.9  3.16      9.8
# 5               7.4             1.8  3.51      9.4
# ...             ...             ...   ...      ...
# 1593            6.8             1.9  3.42      9.5
# 1594            6.2             2.0  3.45     10.5
# 1595            5.9             2.2  3.52     11.2
# 1597            5.9             2.0  3.57     10.2
# 1598            6.0             3.6  3.39     11.0
#
# [1359 rows x 4 columns]

# %%
target
# Out:
#       quality
# 0           5
# 1           5
# 2           5
# 3           6
# 5           5
# ...       ...
# 1593        6
# 1594        5
# 1595        6
# 1597        5
# 1598        6
#
# [1359 rows x 1 columns]

# %%
corr = predictors.corr()
corr
# Out:
#                 fixed acidity  residual sugar        pH   alcohol
# fixed acidity        1.000000        0.111025 -0.686685 -0.061596
# residual sugar       0.111025        1.000000 -0.083143  0.063281
# pH                  -0.686685       -0.083143  1.000000  0.213418
# alcohol             -0.061596        0.063281  0.213418  1.000000

# %%
sns.heatmap(corr)
plt.title('Matriz de Correlación')
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.25, random_state=13)

# %%
plot_tree(arbol)
# Out:
# [Text(0.5402704041407274, 0.9761904761904762, 'x[3] <= 10.525\ngini = 0.654\nsamples = 1019\nvalue = [7, 43, 431, 394, 129, 15]'),
#  Text(0.2981184213220839, 0.9285714285714286, 'x[3] <= 9.85\ngini = 0.548\nsamples = 615\nvalue = [5.0, 27.0, 364.0, 193.0, 24.0, 2.0]'),
#  Text(0.4191944127314056, 0.9523809523809523, 'True  '),
#  Text(0.19756384133355176, 0.8809523809523809, 'x[0] <= 10.05\ngini = 0.473\nsamples = 387\nvalue = [3.0, 19.0, 263.0, 97.0, 4.0, 1.0]'),
#  Text(0.09860081503931847, 0.8333333333333334, 'x[2] <= 3.285\ngini = 0.445\nsamples = 355\nvalue = [2.0, 16.0, 251.0, 82.0, 4.0, 0.0]'),
#  Text(0.04652686762778506, 0.7857142857142857, 'x[2] <= 2.92\ngini = 0.31\nsamples = 167\nvalue = [0, 2, 136, 27, 2, 0]'),
#  Text(0.043905635648754916, 0.7380952380952381, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.0491480996068152, 0.7380952380952381, 'x[3] <= 9.45\ngini = 0.304\nsamples = 166\nvalue = [0, 2, 136, 26, 2, 0]'),
# ...

# %%
tree = DecisionTreeClassifier()

# %%
arbol = tree.fit(X_train, y_train)

# %%
predicciones = arbol.predict(X_test)

# %%
predicciones
# Out:
# array([5, 7, 6, 5, 5, 5, 6, 5, 6, 6, 5, 6, 5, 7, 4, 6, 5, 5, 5, 4, 4, 4,
#        6, 6, 7, 6, 7, 6, 4, 6, 5, 5, 5, 6, 5, 5, 6, 5, 7, 6, 6, 6, 6, 6,
#        6, 6, 6, 5, 6, 5, 5, 5, 5, 7, 5, 5, 5, 6, 6, 6, 5, 7, 6, 5, 5, 6,
#        5, 5, 6, 4, 7, 6, 4, 6, 5, 5, 6, 6, 6, 6, 5, 6, 5, 6, 6, 6, 7, 6,
#        5, 5, 5, 6, 5, 6, 5, 5, 5, 7, 6, 4, 6, 5, 7, 6, 6, 6, 5, 6, 6, 7,
#        5, 6, 5, 5, 6, 6, 5, 6, 5, 6, 6, 6, 6, 6, 6, 5, 5, 7, 5, 7, 5, 6,
#        6, 5, 7, 7, 6, 4, 5, 6, 6, 6, 6, 5, 6, 7, 6, 5, 5, 5, 7, 6, 6, 6,
#        6, 6, 6, 5, 6, 5, 5, 6, 8, 5, 5, 5, 6, 4, 6, 5, 5, 5, 6, 5, 4, 5,
#        6, 5, 6, 7, 5, 4, 8, 6, 5, 7, 7, 7, 5, 7, 5, 6, 5, 5, 5, 5, 7, 7,
#        6, 6, 8, 6, 5, 5, 6, 7, 6, 4, 5, 4, 6, 5, 6, 6, 6, 5, 5, 5, 6, 6,
#        5, 5, 7, 5, 6, 6, 7, 7, 6, 5, 6, 5, 6, 8, 6, 4, 5, 5, 5, 7, 6, 4,
#        7, 7, 6, 5, 7, 6, 6, 6, 5, 7, 5, 6, 4, 6, 6, 5, 6, 7, 6, 6, 6, 7,
#        5, 6, 7, 5, 5, 6, 5, 6, 6, 5, 5, 5, 5, 5, 6, 7, 6, 5, 4, 7, 5, 6,
# ...

# %%
pd.crosstab(np.array([y[0] for y in y_test.values.tolist()]), predicciones, rownames=['Actual'], colnames=['Predicciones'])
# Out:
# Predicciones   4   5   6   7  8
# Actual
# 3              0   2   1   0  0
# 4              1   4   3   2  0
# 5              9  80  50   6  1
# 6             11  45  64  19  2
# 7              0   7  17  13  1
# 8              0   0   0   2  0

# %%
accuracy = accuracy_score(y_test,predicciones)
accuracy
# Out:
# 0.4647058823529412

# %%
precision = precision_score(y_test, predicciones, average='weighted')
precision
# Out:
# C:\Users\daveg\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 0.4815300612998823

# %%
recall = recall_score(y_test, predicciones, average='weighted')
recall
# Out:
# 0.4647058823529412

# %%
f1 = f1_score(y_test, predicciones, average='weighted')
f1
# Out:
# 0.47247054930855653
